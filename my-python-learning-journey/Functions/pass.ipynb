# %%
a=("SALAM ALLHA HU AKABA")
print(a)
# Out:
# SALAM ALLHA HU AKABA

# %%
x=10
if x >5:
    pass
else:
    print("x is 5 or less")

# %%
n=10
if n > 10:
    pass
print("HELLO")

#________________________________________
if x > 10:
    pass
else:
    print("less than 10")
# Out:
# HELLO
# less than 10

# %%
class person:
    def_init_(self,name,age):
    self.name= name
    self.age=age
    def greet(self):
        pass
p=person("Sam", 23)
# Out:
#   Cell In[21], line 2
#     def_init_(self,name,age):
#                             ^
# SyntaxError: invalid syntax

# %%
for i in range(5):
    if i==3:
        pass #Do Nothing When i is 3
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
#
